# %%
import pandas as pd

# %%
players = pd.read_csv('data/interim/all_player_stats_00-24.csv')
all_stars = pd.read_csv('data/interim/allstar_stats_00-24.csv')

# %%
all_stars
# Out:
#               Player   Season  All Star
# 0       LeBron James  2008-09      True
# 1       LeBron James  2012-13      True
# 2       Kevin Durant  2013-14      True
# 3       Kevin Durant  2012-13      True
# 4       LeBron James  2009-10      True
# ..               ...      ...       ...
# 595   Deron Williams  2011-12      True
# 596    Tracy McGrady  2005-06      True
# 597    Julius Randle  2023-24      True
# 598  Anthony Edwards  2022-23      True
# 599  Jermaine O'Neal  2004-05      True
#
# [600 rows x 3 columns]

# %%
players
# Out:
#          Rk           Player    WS  MP/G   Season  Age    Team   G  GS  AS  \
# 0         1     LeBron James  20.3  37.7  2008-09   24     CLE  81  81   1
# 1         2     LeBron James  19.3  37.9  2012-13   28     MIA  76  76   1
# 2         3     Kevin Durant  19.2  38.5  2013-14   25     OKC  81  81   1
# 3         4     Kevin Durant  18.9  38.5  2012-13   24     OKC  81  81   1
# 4         5     LeBron James  18.5  39.0  2009-10   25     CLE  76  76   1
# ...     ...              ...   ...   ...      ...  ...     ...  ..  ..  ..
# 9995   9996  Stephon Marbury  -0.3  18.0  2008-09   31     BOS  23   4   0
# 9996   9997         Art Long  -0.3   8.1  2002-03   30  PHITOR  26   0   0
# 9997   9998   Jamaal Tinsley  -0.3  15.5  2009-10   31     MEM  38   1   0
# 9998   9999       Eddy Curry  -0.3   8.9  2009-10   27     NYK   7   0   0
# 9999  10000      Evan Turner  -0.3  13.2  2019-20   31     ATL  19   0   0
#
# ...

# %%
all_stars = all_stars[['Player', 'Season']]
all_stars['All Star'] = True
all_stars
# Out:
# /var/folders/yj/rwz2nz615t76n6wxvqtw5mcc0000gn/T/ipykernel_34327/151180072.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_stars['All Star'] = True
#               Player   Season  All Star
# 0       LeBron James  2008-09      True
# 1       LeBron James  2012-13      True
# 2       Kevin Durant  2013-14      True
# 3       Kevin Durant  2012-13      True
# 4       LeBron James  2009-10      True
# ..               ...      ...       ...
# 595   Deron Williams  2011-12      True
# 596    Tracy McGrady  2005-06      True
# 597    Julius Randle  2023-24      True
# 598  Anthony Edwards  2022-23      True
# 599  Jermaine O'Neal  2004-05      True
#
# [600 rows x 3 columns]

# %%
df = pd.merge(players, all_stars, on=['Player', 'Season'], how='outer')

# %%
df['All Star'] = df['All Star'].fillna(False)

# %%
df
# Out:
#          Rk           Player    WS  MP/G   Season  Age    Team   G  GS  AS  \
# 0         1     LeBron James  20.3  37.7  2008-09   24     CLE  81  81   1
# 1         2     LeBron James  19.3  37.9  2012-13   28     MIA  76  76   1
# 2         3     Kevin Durant  19.2  38.5  2013-14   25     OKC  81  81   1
# 3         4     Kevin Durant  18.9  38.5  2012-13   24     OKC  81  81   1
# 4         5     LeBron James  18.5  39.0  2009-10   25     CLE  76  76   1
# ...     ...              ...   ...   ...      ...  ...     ...  ..  ..  ..
# 9995   9996  Stephon Marbury  -0.3  18.0  2008-09   31     BOS  23   4   0
# 9996   9997         Art Long  -0.3   8.1  2002-03   30  PHITOR  26   0   0
# 9997   9998   Jamaal Tinsley  -0.3  15.5  2009-10   31     MEM  38   1   0
# 9998   9999       Eddy Curry  -0.3   8.9  2009-10   27     NYK   7   0   0
# 9999  10000      Evan Turner  -0.3  13.2  2019-20   31     ATL  19   0   0
#
# ...

# %%
df.to_csv('data/external/player_stats_short.csv')
