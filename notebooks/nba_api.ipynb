# %%
import pandas as pd
from nba_api.stats.endpoints import playercareerstats, commonplayerinfo, cumestatsplayer, playergamelog
from nba_api.stats.endpoints import draftcombinestats, draftcombinedrillresults, draftcombineplayeranthro, draftcombinespotshooting, draftcombinenonstationaryshooting, drafthistory
from nba_api.stats.static import players

# %%
all_players = pd.json_normalize(players.get_players())
player_id = 1627759

# %%
playercareerstats.PlayerCareerStats(player_id=player_id).get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0    1627759   2016-17        00  1610612738               BOS        20.0
# 1    1627759   2017-18        00  1610612738               BOS        21.0
# 2    1627759   2018-19        00  1610612738               BOS        22.0
# 3    1627759   2019-20        00  1610612738               BOS        23.0
# 4    1627759   2020-21        00  1610612738               BOS        24.0
# 5    1627759   2021-22        00  1610612738               BOS        25.0
# 6    1627759   2022-23        00  1610612738               BOS        26.0
# 7    1627759   2023-24        00  1610612738               BOS        27.0
#
#    GP  GS     MIN  FGM  ...  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV   PF  \
# 0  78  20  1341.0  192  ...   0.685    45   175  220   64   35   18   68  142
# 1  70  70  2152.0  373  ...   0.644    66   280  346  114   70   26  124  181
# ...

# %%
commonplayerinfo.CommonPlayerInfo(player_id=player_id).get_data_frames()[0]
# Out:
#    PERSON_ID FIRST_NAME LAST_NAME DISPLAY_FIRST_LAST DISPLAY_LAST_COMMA_FIRST  \
# 0    1627759     Jaylen     Brown       Jaylen Brown            Brown, Jaylen
#
#   DISPLAY_FI_LAST   PLAYER_SLUG            BIRTHDATE      SCHOOL COUNTRY  ...  \
# 0        J. Brown  jaylen-brown  1996-10-24T00:00:00  California     USA  ...
#
#      PLAYERCODE FROM_YEAR TO_YEAR  DLEAGUE_FLAG NBA_FLAG GAMES_PLAYED_FLAG  \
# 0  jaylen_brown      2016    2024             N        Y                 Y
#
#   DRAFT_YEAR DRAFT_ROUND  DRAFT_NUMBER GREATEST_75_FLAG
# 0       2016           1             3                N
#
# [1 rows x 33 columns]

# %%
playergamelog.PlayerGameLog(player_id=player_id).get_data_frames()[0]
# Out:
#    SEASON_ID  Player_ID     Game_ID     GAME_DATE      MATCHUP WL  MIN  FGM  \
# 0      22023    1627759  0022301167  APR 11, 2024  BOS vs. NYK  L   29    6
# 1      22023    1627759  0022301148  APR 09, 2024    BOS @ MIL  L   36    7
# 2      22023    1627759  0022301134  APR 07, 2024  BOS vs. POR  W   30   10
# 3      22023    1627759  0022301105  APR 03, 2024  BOS vs. OKC  W   33    9
# 4      22023    1627759  0022301074  MAR 30, 2024    BOS @ NOP  W   35    6
# ..       ...        ...         ...           ...          ... ..  ...  ...
# 65     22023    1627759  0022300136  NOV 04, 2023    BOS @ BKN  W   35    7
# 66     22023    1627759  0022300118  NOV 01, 2023  BOS vs. IND  W   25    7
# 67     22023    1627759  0022300103  OCT 30, 2023    BOS @ WAS  W   32   13
# 68     22023    1627759  0022300080  OCT 27, 2023  BOS vs. MIA  W   34   11
# 69     22023    1627759  0022300065  OCT 25, 2023    BOS @ NYK  W   38    4
#
# ...

# %%
game_list = playergamelog.PlayerGameLog(player_id=player_id).get_data_frames()[0]['Game_ID'].to_list()

# %%
cumestatsplayer.CumeStatsPlayer(player_id=player_id, game_ids=game_list).get_data_frames()[0]
# Out:
#      DATE_EST VISITOR_TEAM HOME_TEAM  GP  GS  ACTUAL_MINUTES  ACTUAL_SECONDS  \
# 0  04/11/2024       Knicks   Celtics   1   1              28              38
#
#    FG  FGA  FG_PCT  ...  TOT_REB  AVG_TOT_REB  AST  PF  DQ  STL  TURNOVERS  \
# 0   6   15     0.4  ...        2          2.0    1   3   0    0          3
#
#    BLK  PTS  AVG_PTS
# 0    2   15     15.0
#
# [1 rows x 28 columns]

# %%
draftcombinestats.DraftCombineStats().get_data_frames()[0]
# Out:
#    SEASON  PLAYER_ID FIRST_NAME   LAST_NAME        PLAYER_NAME POSITION  \
# 0    2023    1641725       Trey   Alexander     Trey Alexander       SG
# 1    2023    1641735      Amari      Bailey       Amari Bailey       SG
# 2    2023    1641734      Emoni       Bates        Emoni Bates       SF
# 3    2023    1641736      Reece     Beekman      Reece Beekman       PG
# 4    2023    1641710    Anthony       Black      Anthony Black       PG
# ..    ...        ...        ...         ...                ...      ...
# 76   2023    1641705     Victor  Wembanyama  Victor Wembanyama        C
# 77   2023    1641727      Dariq   Whitehead    Dariq Whitehead       SG
# 78   2023    1641715        Cam    Whitmore       Cam Whitmore       SF
# 79   2023    1630592      Jalen      Wilson       Jalen Wilson       SF
# 80   2023    1631209     Isaiah        Wong        Isaiah Wong       SG
#
#     HEIGHT_WO_SHOES HEIGHT_WO_SHOES_FT_IN HEIGHT_W_SHOES HEIGHT_W_SHOES_FT_IN  \
# ...

# %%
draftcombinenonstationaryshooting.DraftCombineNonStationaryShooting().get_data_frames()[0]
# Out:
#     TEMP_PLAYER_ID  PLAYER_ID FIRST_NAME   LAST_NAME        PLAYER_NAME  \
# 0          1641725    1641725       Trey   Alexander     Trey Alexander
# 1          1641735    1641735      Amari      Bailey       Amari Bailey
# 2          1641734    1641734      Emoni       Bates        Emoni Bates
# 3          1641736    1641736      Reece     Beekman      Reece Beekman
# 4          1641710    1641710    Anthony       Black      Anthony Black
# ..             ...        ...        ...         ...                ...
# 76         1641705    1641705     Victor  Wembanyama  Victor Wembanyama
# 77         1641727    1641727      Dariq   Whitehead    Dariq Whitehead
# 78         1641715    1641715        Cam    Whitmore       Cam Whitmore
# 79         1630592    1630592      Jalen      Wilson       Jalen Wilson
# 80         1631209    1631209     Isaiah        Wong        Isaiah Wong
#
#    POSITION OFF_DRIB_FIFTEEN_BREAK_LEFT_MADE  \
# 0        SG                             None
# ...

# %%
draftcombinespotshooting.DraftCombineSpotShooting(season_year=2000).get_data_frames()[0]
# Out:
#    TEMP_PLAYER_ID  PLAYER_ID FIRST_NAME  LAST_NAME       PLAYER_NAME POSITION  \
# 0            None       2124      Malik      Allen       Malik Allen     PF-C
# 1            None      12019     Harold  Arceneaux  Harold Arceneaux    SG-SF
# 2            None      12020     Lamont     Barnes     Lamont Barnes     PF-C
# 3            None      12131      Mario      Bland       Mario Bland       PF
# 4            None       2056     Primoz     Brezec     Primoz Brezec        C
# ..            ...        ...        ...        ...               ...      ...
# 60           None       2074     Jabari      Smith      Jabari Smith     PF-C
# 61           None      12027    Jarrett   Stephens  Jarrett Stephens       PF
# 62           None      12028     Bootsy   Thornton   Bootsy Thornton       SG
# 63           None      12029     Jaquay      Walls      Jaquay Walls       PG
# 64           None      12030     Jameel    Watkins    Jameel Watkins     PF-C
#
# ...

# %%
draftcombineplayeranthro.DraftCombinePlayerAnthro().get_data_frames()[0]
# Out:
#     TEMP_PLAYER_ID  PLAYER_ID FIRST_NAME   LAST_NAME        PLAYER_NAME  \
# 0          1641725    1641725       Trey   Alexander     Trey Alexander
# 1          1641735    1641735      Amari      Bailey       Amari Bailey
# 2          1641734    1641734      Emoni       Bates        Emoni Bates
# 3          1641736    1641736      Reece     Beekman      Reece Beekman
# 4          1641710    1641710    Anthony       Black      Anthony Black
# ..             ...        ...        ...         ...                ...
# 76         1641705    1641705     Victor  Wembanyama  Victor Wembanyama
# 77         1641727    1641727      Dariq   Whitehead    Dariq Whitehead
# 78         1641715    1641715        Cam    Whitmore       Cam Whitmore
# 79         1630592    1630592      Jalen      Wilson       Jalen Wilson
# 80         1631209    1631209     Isaiah        Wong        Isaiah Wong
#
#    POSITION  HEIGHT_WO_SHOES HEIGHT_WO_SHOES_FT_IN HEIGHT_W_SHOES  \
# ...

# %%
draftcombinedrillresults.DraftCombineDrillResults(season_year=2000).get_data_frames()[0]
# Out:
#    TEMP_PLAYER_ID  PLAYER_ID FIRST_NAME  LAST_NAME       PLAYER_NAME POSITION  \
# 0            None       2124      Malik      Allen       Malik Allen     PF-C
# 1            None      12019     Harold  Arceneaux  Harold Arceneaux    SG-SF
# 2            None      12020     Lamont     Barnes     Lamont Barnes     PF-C
# 3            None      12131      Mario      Bland       Mario Bland       PF
# 4            None       2056     Primoz     Brezec     Primoz Brezec        C
# ..            ...        ...        ...        ...               ...      ...
# 60           None       2074     Jabari      Smith      Jabari Smith     PF-C
# 61           None      12027    Jarrett   Stephens  Jarrett Stephens       PF
# 62           None      12028     Bootsy   Thornton   Bootsy Thornton       SG
# 63           None      12029     Jaquay      Walls      Jaquay Walls       PG
# 64           None      12030     Jameel    Watkins    Jameel Watkins     PF-C
#
# ...

# %%
drafthistory.DraftHistory(season_year_nullable=None).get_data_frames()[0]
# Out:
#       PERSON_ID        PLAYER_NAME SEASON  ROUND_NUMBER  ROUND_PICK  \
# 0       1641705  Victor Wembanyama   2023             1           1
# 1       1641706     Brandon Miller   2023             1           2
# 2       1630703    Scoot Henderson   2023             1           3
# 3       1641708      Amen Thompson   2023             1           4
# 4       1641709     Ausar Thompson   2023             1           5
# ...         ...                ...    ...           ...         ...
# 8252      77036       Paul Hoffman   1947             0           0
# 8253      76773     Harry Gallatin   1947             0           0
# 8254      77072        Bob Hubbard   1947             0           0
# 8255      76769    Elmer R. Gainer   1947             0           0
# 8256      78023     Irv Rothenberg   1947             0           0
#
#       OVERALL_PICK DRAFT_TYPE     TEAM_ID    TEAM_CITY      TEAM_NAME  \
# 0                1      Draft  1610612759  San Antonio          Spurs
# ...
