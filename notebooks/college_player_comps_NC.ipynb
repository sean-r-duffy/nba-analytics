# %% [markdown]
# ## This notebook processes data for performing the nearest neighbors opperations, as well as outputs the rookie -> NBA projected stats.

# %%
import pandas as pd

# %% [markdown]
# ## College Data

# %% [markdown]
# Read in scraped college data

# %%
df = pd.read_csv("../data/interim/college_player_stats_00-24.csv")
df
# Out:
#         Rk           Player  PTS/G Draft Team  Round  Pick  Draft Year  \
# 0        1  Jimmer Fredette   28.9        MIL      1    10        2011
# 1        2    Adam Morrison   28.1        CHA      1     3        2006
# 2        3       Trae Young   27.4        DAL      1     5        2018
# 3        4      J.J. Redick   26.8        ORL      1    11        2006
# 4        5   Doug McDermott   26.7        DEN      1    11        2014
# ...    ...              ...    ...        ...    ...   ...         ...
# 1595  1596   Vernon Macklin    2.9        DET      2    52        2011
# 1596  1597     Andy Rautins    2.9        NYK      2    38        2010
# 1597  1598  Marcus Williams    2.9        NJN      1    22        2006
# 1598  1599    Moritz Wagner    2.9        LAL      1    25        2018
# 1599  1600       Royal Ivey    2.8        ATL      2    37        2004
#
#       Draft College   Season           Team  ...   PTS    FG%    2P%    3P%  \
# 0     Brigham Young  2010-11  Brigham Young  ...  28.9  0.452  0.491  0.396
# 1           Gonzaga  2005-06        Gonzaga  ...  28.1  0.496  0.523  0.428
# 2          Oklahoma  2017-18       Oklahoma  ...  27.4  0.422  0.493  0.360
# 3              Duke  2005-06           Duke  ...  26.8  0.470  0.521  0.421
# 4         Creighton  2013-14      Creighton  ...  26.7  0.526  0.567  0.449
# ...             ...      ...            ...  ...   ...    ...    ...    ...
# 1595        Florida  2006-07     Georgetown  ...   2.9  0.741  0.741    NaN
# 1596       Syracuse  2005-06       Syracuse  ...   2.9  0.377  0.714  0.326
# 1597    Connecticut  2003-04    Connecticut  ...   2.9  0.370  0.483  0.176
# 1598       Michigan  2015-16       Michigan  ...   2.9  0.607  0.714  0.167
# 1599          Texas  2000-01          Texas  ...   2.8  0.365  0.384  0.250
#
#         FT%    TS%   eFG%  Pos  Class              -9999
# 0     0.894  0.594  0.533    G     SR  jimmer-fredette-1
# 1     0.772  0.605  0.556    F     JR    adam-morrison-1
# 2     0.861  0.585  0.518    G     FR       trae-young-1
# 3     0.863  0.630  0.578    G     SR        jj-redick-1
# 4     0.864  0.644  0.603    F     SR   doug-mcdermott-1
# ...     ...    ...    ...  ...    ...                ...
# 1595  0.435  0.693  0.741    F     FR   vernon-macklin-1
# 1596  0.500  0.519  0.519    G     FR     andy-rautins-1
# 1597  0.692  0.441  0.402    G     FR  marcus-williams-1
# 1598  0.556  0.618  0.623    F     FR    moritz-wagner-1
# 1599  0.659  0.444  0.382    G     FR       royal-ivey-1
#
# [1600 rows x 39 columns]

# %%
df.columns
# Out:
# Index(['Rk', 'Player', 'PTS/G', 'Draft Team', 'Round', 'Pick', 'Draft Year',
#        'Draft College', 'Season', 'Team', 'G', 'GS', 'MP', 'FG', 'FGA', '2P',
#        '2PA', '3P', '3PA', 'FT', 'FTA', 'ORB', 'DRB', 'TRB', 'AST', 'STL',
#        'BLK', 'TOV', 'PF', 'PTS', 'FG%', '2P%', '3P%', 'FT%', 'TS%', 'eFG%',
#        'Pos', 'Class', '-9999'],
#       dtype='object')

# %% [markdown]
# Remove unneeded columns

# %%
df = df.drop(['PTS/G', 'Draft Team', 'Round', 'Pick', 'Draft Year', 'Draft College','Rk', '-9999'], axis=1)
df.columns
# Out:
# Index(['Player', 'Season', 'Team', 'G', 'GS', 'MP', 'FG', 'FGA', '2P', '2PA',
#        '3P', '3PA', 'FT', 'FTA', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK',
#        'TOV', 'PF', 'PTS', 'FG%', '2P%', '3P%', 'FT%', 'TS%', 'eFG%', 'Pos',
#        'Class'],
#       dtype='object')

# %% [markdown]
# Convert Position into 1 hot encodings

# %%
pos_dummies = pd.get_dummies(df['Pos']).astype(int)
pos_dummies
# Out:
#       C  F  G
# 0     0  0  1
# 1     0  1  0
# 2     0  0  1
# 3     0  0  1
# 4     0  1  0
# ...  .. .. ..
# 1595  0  1  0
# 1596  0  0  1
# 1597  0  0  1
# 1598  0  1  0
# 1599  0  0  1
#
# [1600 rows x 3 columns]

# %%
df["Pos_G"] = pos_dummies["G"]
df["Pos_F"] = pos_dummies["F"]
df["Pos_C"] = pos_dummies["C"]
df = df.drop('Pos', axis=1)
df.columns
# Out:
# Index(['Player', 'Season', 'Team', 'G', 'GS', 'MP', 'FG', 'FGA', '2P', '2PA',
#        '3P', '3PA', 'FT', 'FTA', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK',
#        'TOV', 'PF', 'PTS', 'FG%', '2P%', '3P%', 'FT%', 'TS%', 'eFG%', 'Class',
#        'Pos_G', 'Pos_F', 'Pos_C'],
#       dtype='object')

# %% [markdown]
# Features to be used for model

# %%
features = ['Player', 'Season', 'Team', '2P',
       '3P', 'FT','ORB', 'DRB', 'AST', 'STL', 'BLK',
       'TOV', 'PF', 'PTS', 'FG%', "Pos_G", "Pos_F", "Pos_C"]

# %%
df[features]
# Out:
#                Player   Season           Team   2P   3P   FT  ORB  DRB  AST  \
# 0     Jimmer Fredette  2010-11  Brigham Young  6.0  3.4  6.8  0.6  2.8  4.3
# 1       Adam Morrison  2005-06        Gonzaga  7.0  2.2  7.3  1.4  4.1  1.7
# 2          Trae Young  2017-18       Oklahoma  4.5  3.7  7.4  0.4  3.5  8.7
# 3         J.J. Redick  2005-06           Duke  4.5  3.9  6.1  0.2  1.8  2.6
# 4      Doug McDermott  2013-14      Creighton  6.7  2.7  5.1  1.6  5.3  1.6
# ...               ...      ...            ...  ...  ...  ...  ...  ...  ...
# 1595   Vernon Macklin  2006-07     Georgetown  1.3  0.0  0.3  0.7  0.7  0.5
# 1596     Andy Rautins  2005-06       Syracuse  0.3  0.8  0.2  0.3  0.6  0.7
# 1597  Marcus Williams  2003-04    Connecticut  0.9  0.2  0.6  0.4  0.9  4.3
# 1598    Moritz Wagner  2015-16       Michigan  1.2  0.1  0.3  0.7  0.9  0.1
# 1599       Royal Ivey  2000-01          Texas  0.8  0.1  0.9  0.3  1.3  1.7
#
#       STL  BLK  TOV   PF   PTS    FG%  Pos_G  Pos_F  Pos_C
# 0     1.3  0.0  3.5  1.3  28.9  0.452      1      0      0
# 1     1.1  0.3  2.3  2.0  28.1  0.496      0      1      0
# 2     1.7  0.3  5.2  1.8  27.4  0.422      1      0      0
# 3     1.4  0.1  2.5  1.5  26.8  0.470      1      0      0
# 4     0.2  0.1  1.8  1.9  26.7  0.526      0      1      0
# ...   ...  ...  ...  ...   ...    ...    ...    ...    ...
# 1595  0.0  0.1  0.5  1.0   2.9  0.741      0      1      0
# 1596  0.3  0.1  0.2  1.2   2.9  0.377      1      0      0
# 1597  1.0  0.1  2.4  1.8   2.9  0.370      1      0      0
# 1598  0.2  0.2  0.5  1.6   2.9  0.607      0      1      0
# 1599  0.7  0.2  1.3  2.2   2.8  0.365      1      0      0
#
# [1600 rows x 18 columns]

# %%
temp = df[features].drop(['Season', 'Team'], axis=1)
temp
# Out:
#                Player   2P   3P   FT  ORB  DRB  AST  STL  BLK  TOV   PF   PTS  \
# 0     Jimmer Fredette  6.0  3.4  6.8  0.6  2.8  4.3  1.3  0.0  3.5  1.3  28.9
# 1       Adam Morrison  7.0  2.2  7.3  1.4  4.1  1.7  1.1  0.3  2.3  2.0  28.1
# 2          Trae Young  4.5  3.7  7.4  0.4  3.5  8.7  1.7  0.3  5.2  1.8  27.4
# 3         J.J. Redick  4.5  3.9  6.1  0.2  1.8  2.6  1.4  0.1  2.5  1.5  26.8
# 4      Doug McDermott  6.7  2.7  5.1  1.6  5.3  1.6  0.2  0.1  1.8  1.9  26.7
# ...               ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...   ...
# 1595   Vernon Macklin  1.3  0.0  0.3  0.7  0.7  0.5  0.0  0.1  0.5  1.0   2.9
# 1596     Andy Rautins  0.3  0.8  0.2  0.3  0.6  0.7  0.3  0.1  0.2  1.2   2.9
# 1597  Marcus Williams  0.9  0.2  0.6  0.4  0.9  4.3  1.0  0.1  2.4  1.8   2.9
# 1598    Moritz Wagner  1.2  0.1  0.3  0.7  0.9  0.1  0.2  0.2  0.5  1.6   2.9
# 1599       Royal Ivey  0.8  0.1  0.9  0.3  1.3  1.7  0.7  0.2  1.3  2.2   2.8
#
#         FG%  Pos_G  Pos_F  Pos_C
# 0     0.452      1      0      0
# 1     0.496      0      1      0
# 2     0.422      1      0      0
# 3     0.470      1      0      0
# 4     0.526      0      1      0
# ...     ...    ...    ...    ...
# 1595  0.741      0      1      0
# 1596  0.377      1      0      0
# 1597  0.370      1      0      0
# 1598  0.607      0      1      0
# 1599  0.365      1      0      0
#
# [1600 rows x 16 columns]

# %% [markdown]
# Combine Seasons to get college averages across years for player stats

# %%
col_career_avgs = temp.groupby('Player').mean().reset_index()
col_career_avgs
# Out:
#               Player   2P    3P    FT   ORB   DRB   AST  STL   BLK   TOV  \
# 0       A.J. Hammons  5.2  0.10  2.70  2.35  5.00  1.00  0.4  2.65  2.05
# 1         A.J. Price  2.9  1.95  2.95  0.70  2.85  5.25  1.0  0.05  2.55
# 2         AJ Griffin  1.9  1.80  1.10  0.80  3.20  1.00  0.5  0.60  0.60
# 3       Aaron Brooks  3.8  2.30  3.30  0.90  3.40  4.30  1.4  0.20  2.50
# 4       Aaron Gordon  4.6  0.40  2.00  2.70  5.30  2.00  0.9  1.00  1.40
# ..               ...  ...   ...   ...   ...   ...   ...  ...   ...   ...
# 853     Zach Collins  3.2  0.30  2.80  1.70  4.20  0.40  0.5  1.80  1.50
# 854      Zach LaVine  2.1  1.30  1.30  0.50  2.10  1.80  0.9  0.20  1.10
# 855    Zach Randolph  4.2  0.00  2.40  3.10  3.60  1.00  0.7  0.70  1.60
# 856     Zhaire Smith  3.7  0.50  2.50  2.20  2.80  1.80  1.1  1.10  1.10
# 857  Zion Williamson  8.2  0.70  3.90  3.50  5.40  2.10  2.1  1.80  2.40
#
#        PF    PTS     FG%  Pos_G  Pos_F  Pos_C
# 0    2.50  13.45  0.5660    0.0    0.0    1.0
# 1    1.45  14.60  0.4225    1.0    0.0    0.0
# 2    1.10  10.40  0.4930    0.0    1.0    0.0
# 3    2.50  17.70  0.4600    1.0    0.0    0.0
# 4    2.40  12.40  0.4950    0.0    1.0    0.0
# ..    ...    ...     ...    ...    ...    ...
# 853  2.70  10.00  0.6520    0.0    1.0    0.0
# 854  2.00   9.40  0.4410    1.0    0.0    0.0
# 855  1.80  10.80  0.5870    0.0    0.0    1.0
# 856  1.80  11.30  0.5560    1.0    0.0    0.0
# 857  2.10  22.60  0.6800    0.0    1.0    0.0
#
# [858 rows x 16 columns]

# %% [markdown]
# Reduce college data to players that we have NBA data on

# %%
temp = pd.read_csv("../data/processed/player_data_clean.csv")
p_in_db = list(temp['player'].unique())
col_career_avgs = col_career_avgs[col_career_avgs["Player"].isin(p_in_db)]
col_career_avgs
# Out:
#               Player    2P   3P        FT       ORB       DRB  AST  STL  \
# 2         AJ Griffin  1.90  1.8  1.100000  0.800000  3.200000  1.0  0.5
# 3       Aaron Brooks  3.80  2.3  3.300000  0.900000  3.400000  4.3  1.4
# 4       Aaron Gordon  4.60  0.4  2.000000  2.700000  5.300000  2.0  0.9
# 5         Aaron Gray  4.20  0.0  2.366667  2.733333  4.833333  1.4  0.4
# 6      Aaron Holiday  3.25  2.1  3.600000  0.400000  2.850000  5.1  1.2
# ..               ...   ...  ...       ...       ...       ...  ...  ...
# 850     Xavier Henry  2.60  1.9  2.500000  1.200000  3.200000  1.5  1.5
# 853     Zach Collins  3.20  0.3  2.800000  1.700000  4.200000  0.4  0.5
# 854      Zach LaVine  2.10  1.3  1.300000  0.500000  2.100000  1.8  0.9
# 855    Zach Randolph  4.20  0.0  2.400000  3.100000  3.600000  1.0  0.7
# 857  Zion Williamson  8.20  0.7  3.900000  3.500000  5.400000  2.1  2.1
#
#           BLK       TOV        PF   PTS       FG%  Pos_G  Pos_F  Pos_C
# 2    0.600000  0.600000  1.100000  10.4  0.493000    0.0    1.0    0.0
# 3    0.200000  2.500000  2.500000  17.7  0.460000    1.0    0.0    0.0
# 4    1.000000  1.400000  2.400000  12.4  0.495000    0.0    1.0    0.0
# 5    1.266667  1.733333  2.266667  10.7  0.555667    0.0    0.0    1.0
# 6    0.200000  3.100000  2.450000  16.3  0.473000    1.0    0.0    0.0
# ..        ...       ...       ...   ...       ...    ...    ...    ...
# 850  0.500000  1.900000  1.800000  13.4  0.458000    1.0    0.0    0.0
# 853  1.800000  1.500000  2.700000  10.0  0.652000    0.0    1.0    0.0
# 854  0.200000  1.100000  2.000000   9.4  0.441000    1.0    0.0    0.0
# 855  0.700000  1.600000  1.800000  10.8  0.587000    0.0    0.0    1.0
# 857  1.800000  2.400000  2.100000  22.6  0.680000    0.0    1.0    0.0
#
# [571 rows x 16 columns]

# %% [markdown]
# ## Prospects
#
# Loading in list of draftable players

# %%
prospects = pd.read_csv("../data/processed/draft_prospects.csv", encoding='ISO-8859-1')
prospects
# Out:
#                 NAME POS  AGE                        SCHOOL/CLUB  HEIGHT  \
# 0      Melvin Ajinca   F   20  Saint-Quentin Basketball (France)   45451
# 1     Trey Alexander   G   21                          Creighton   45446
# 2      Reece Beekman   G   22                           Virginia   45444
# 3          Adem Bona   C   21                               UCLA   45451
# 4      Jalen Bridges   G   23                             Baylor   45450
# ..               ...  ..  ...                                ...     ...
# 73       Kel'el Ware   C   20                            Indiana   36708
# 74      Anton Watson   F   23                            Gonzaga   45451
# 75      Jaylen Wells   F   20                   Washington State   45450
# 76     Cody Williams   F   19                           Colorado   45450
# 77  Tristan da Silva   F   23                           Colorado   45451
#
#     WEIGHT         STATUS  COUNTRY
# 0      218  International   France
# 1      187         Junior      USA
# 2      196         Senior      USA
# 3      243      Sophomore  Nigeria
# 4      213         Senior      USA
# ..     ...            ...      ...
# 73     230      Sophomore      USA
# 74     230         Senior      USA
# 75     206         Junior      USA
# 76     178       Freshman      USA
# 77     217         Senior  Germany
#
# [78 rows x 8 columns]

# %% [markdown]
# Select prospect stats from college data

# %%
prospect_stats = col_career_avgs[col_career_avgs['Player'].isin(prospects['NAME'])]

# %%
# prospect_stats.to_csv("../data/interim/prospect_stats_needsIntl.csv", index=False)

# %% [markdown]
# Manually loading data from internet on International students, * only manual part of data collection and processing since there is no
# international player stats database *

# %%
prospect_stats = pd.read_csv("../data/processed/prospect_stats_w_intl.csv")
prospect_stats
# Out:
#                   Player        2P        3P        FT       ORB       DRB  \
# 0              Adem Bona  3.200000  0.000000  1.400000  2.200000  3.000000
# 1          Ajay Mitchell  5.100000  0.600000  4.500000  0.300000  2.400000
# 2           Anton Watson  3.625000  0.325000  1.775000  1.725000  3.600000
# 3         Antonio Reeves  3.600000  2.450000  2.750000  0.550000  2.550000
# 4      Baylor Scheierman  2.766667  2.633333  2.433333  0.700000  7.633333
# 5           Blake Hinson  1.800000  2.050000  1.900000  1.050000  3.400000
# 6            Cam Spencer  2.400000  2.500000  2.100000  1.100000  3.800000
# 7          Cody Williams  3.800000  0.700000  2.300000  0.700000  2.300000
# 8        DaRon Holmes II  5.600000  1.000000  6.200000  1.700000  6.800000
# 9          Dalton Knecht  4.800000  2.600000  4.400000  0.800000  4.100000
# 10          Devin Carter  3.200000  1.100000  3.400000  1.200000  3.700000
# 11       Donovan Clingan  4.100000  0.050000  1.750000  2.350000  4.150000
# 12       Enrique Freeman  5.600000  0.300000  3.800000  3.450000  8.450000
# 13          Grant Nelson  3.100000  0.800000  3.300000  1.600000  4.300000
# 39  2.925000  1.075000  0.450000  1.675000  2.400000  12.575000  0.515500
# 40  1.600000  1.700000  1.500000  2.500000  2.300000  20.100000  0.446000
# 41  0.400000  0.600000  1.500000  1.100000  2.400000  10.700000  0.614000
# 42  1.275000  0.200000  1.650000  1.925000  1.950000  17.650000  0.618750
# 43  4.900000  0.900000  0.100000  1.300000  2.000000  15.500000  0.444000
# 44  0.800000  0.500000  0.000000  0.600000  2.200000   9.300000  0.375000
# 45  0.300000  0.500000  0.200000  0.700000  1.300000   4.600000  0.449000
# 46  3.000000  0.900000  0.200000  2.700000  2.600000  11.500000  0.427000
# 47  0.700000  0.600000  1.400000  1.500000  2.800000   7.800000  0.562000
# 48  0.700000  0.200000  0.100000  0.600000  0.800000   2.800000  0.355000
# 49  0.700000  0.800000  0.500000  1.600000  2.700000   9.700000  0.443000
# 50  0.800000  0.700000  0.300000  1.100000  2.100000   7.400000  0.476000
# 51  0.900000  1.100000  0.200000  1.400000  2.400000   8.200000  0.367000
# 52  0.900000  0.500000  1.300000  1.100000  1.400000   9.700000  0.520000
# 53  4.100000  0.600000  0.100000  2.000000  2.500000  10.200000  0.495000
#
#     Pos_G  Pos_F  Pos_C
# 0       0      1      0
# 1       1      0      0
# 2       0      1      0
# 3       1      0      0
# 4       1      0      0
# 5       1      0      0
# 6       1      0      0
# 7       0      1      0
# 8       0      1      0
# 9       1      0      0
# 10      1      0      0
# 11      0      0      1
# 12      0      1      0
# 13      0      1      0
# 14      0      1      0
# 15      0      1      0
# 16      0      1      0
# 17      1      0      0
# 18      1      0      0
# 19      0      1      0
# 20      1      0      0
# 21      1      0      0
# 22      1      0      0
# 23      0      1      0
# 24      1      0      0
# 25      0      0      1
# 26      0      0      1
# 27      0      1      0
# 28      0      1      0
# 29      1      0      0
# 30      1      0      0
# 31      1      0      0
# 32      1      0      0
# 33      1      0      0
# 34      1      0      0
# 35      1      0      0
# 36      1      0      0
# 37      1      0      0
# 38      1      0      0
# 39      0      1      0
# 40      1      0      0
# 41      0      1      0
# 42      0      0      1
# 43      1      0      0
# 44      0      1      0
# 45      0      1      0
# 46      0      1      0
# 47      0      0      1
# 48      1      0      0
# 49      0      1      0
# 50      0      1      0
# 51      0      1      0
# 52      0      1      0
# 53      1      0      0

# %% [markdown]
# Remove prospects from college dataset

# %%
player_stats_wout_prospects = col_career_avgs[~col_career_avgs['Player'].isin(prospects['NAME'])]
player_stats_wout_prospects
# Out:
#               Player    2P   3P        FT       ORB       DRB  AST  STL  \
# 2         AJ Griffin  1.90  1.8  1.100000  0.800000  3.200000  1.0  0.5
# 3       Aaron Brooks  3.80  2.3  3.300000  0.900000  3.400000  4.3  1.4
# 4       Aaron Gordon  4.60  0.4  2.000000  2.700000  5.300000  2.0  0.9
# 5         Aaron Gray  4.20  0.0  2.366667  2.733333  4.833333  1.4  0.4
# 6      Aaron Holiday  3.25  2.1  3.600000  0.400000  2.850000  5.1  1.2
# ..               ...   ...  ...       ...       ...       ...  ...  ...
# 850     Xavier Henry  2.60  1.9  2.500000  1.200000  3.200000  1.5  1.5
# 853     Zach Collins  3.20  0.3  2.800000  1.700000  4.200000  0.4  0.5
# 854      Zach LaVine  2.10  1.3  1.300000  0.500000  2.100000  1.8  0.9
# 855    Zach Randolph  4.20  0.0  2.400000  3.100000  3.600000  1.0  0.7
# 857  Zion Williamson  8.20  0.7  3.900000  3.500000  5.400000  2.1  2.1
#
#           BLK       TOV        PF   PTS       FG%  Pos_G  Pos_F  Pos_C
# 2    0.600000  0.600000  1.100000  10.4  0.493000    0.0    1.0    0.0
# 3    0.200000  2.500000  2.500000  17.7  0.460000    1.0    0.0    0.0
# 4    1.000000  1.400000  2.400000  12.4  0.495000    0.0    1.0    0.0
# 5    1.266667  1.733333  2.266667  10.7  0.555667    0.0    0.0    1.0
# 6    0.200000  3.100000  2.450000  16.3  0.473000    1.0    0.0    0.0
# ..        ...       ...       ...   ...       ...    ...    ...    ...
# 850  0.500000  1.900000  1.800000  13.4  0.458000    1.0    0.0    0.0
# 853  1.800000  1.500000  2.700000  10.0  0.652000    0.0    1.0    0.0
# 854  0.200000  1.100000  2.000000   9.4  0.441000    1.0    0.0    0.0
# 855  0.700000  1.600000  1.800000  10.8  0.587000    0.0    0.0    1.0
# 857  1.800000  2.400000  2.100000  22.6  0.680000    0.0    1.0    0.0
#
# [571 rows x 16 columns]

# %%
player_stats_wout_prospects = player_stats_wout_prospects.reset_index(drop=True)
player_stats_wout_prospects
# Out:
#               Player    2P   3P        FT       ORB       DRB  AST  STL  \
# 0         AJ Griffin  1.90  1.8  1.100000  0.800000  3.200000  1.0  0.5
# 1       Aaron Brooks  3.80  2.3  3.300000  0.900000  3.400000  4.3  1.4
# 2       Aaron Gordon  4.60  0.4  2.000000  2.700000  5.300000  2.0  0.9
# 3         Aaron Gray  4.20  0.0  2.366667  2.733333  4.833333  1.4  0.4
# 4      Aaron Holiday  3.25  2.1  3.600000  0.400000  2.850000  5.1  1.2
# ..               ...   ...  ...       ...       ...       ...  ...  ...
# 566     Xavier Henry  2.60  1.9  2.500000  1.200000  3.200000  1.5  1.5
# 567     Zach Collins  3.20  0.3  2.800000  1.700000  4.200000  0.4  0.5
# 568      Zach LaVine  2.10  1.3  1.300000  0.500000  2.100000  1.8  0.9
# 569    Zach Randolph  4.20  0.0  2.400000  3.100000  3.600000  1.0  0.7
# 570  Zion Williamson  8.20  0.7  3.900000  3.500000  5.400000  2.1  2.1
#
#           BLK       TOV        PF   PTS       FG%  Pos_G  Pos_F  Pos_C
# 0    0.600000  0.600000  1.100000  10.4  0.493000    0.0    1.0    0.0
# 1    0.200000  2.500000  2.500000  17.7  0.460000    1.0    0.0    0.0
# 2    1.000000  1.400000  2.400000  12.4  0.495000    0.0    1.0    0.0
# 3    1.266667  1.733333  2.266667  10.7  0.555667    0.0    0.0    1.0
# 4    0.200000  3.100000  2.450000  16.3  0.473000    1.0    0.0    0.0
# ..        ...       ...       ...   ...       ...    ...    ...    ...
# 566  0.500000  1.900000  1.800000  13.4  0.458000    1.0    0.0    0.0
# 567  1.800000  1.500000  2.700000  10.0  0.652000    0.0    1.0    0.0
# 568  0.200000  1.100000  2.000000   9.4  0.441000    1.0    0.0    0.0
# 569  0.700000  1.600000  1.800000  10.8  0.587000    0.0    0.0    1.0
# 570  1.800000  2.400000  2.100000  22.6  0.680000    0.0    1.0    0.0
#
# [571 rows x 16 columns]

# %%
prospect_stats = prospect_stats.sort_values(['Player']).reset_index(drop=True)
prospect_stats.head()
# Out:
#            Player     2P     3P     FT    ORB  DRB    AST   STL    BLK   TOV  \
# 0      AJ Johnson  0.800  0.300  0.300  0.300  1.0  0.700  0.20  0.100  0.60
# 1       Adem Bona  3.200  0.000  1.400  2.200  3.0  0.700  0.60  1.700  1.30
# 2   Ajay Mitchell  5.100  0.600  4.500  0.300  2.4  5.100  1.30  0.300  2.20
# 3  Alexandre Sarr  3.100  0.600  1.700  1.400  3.0  0.900  0.50  1.300  1.10
# 4    Anton Watson  3.625  0.325  1.775  1.725  3.6  2.025  1.45  0.575  1.15
#
#      PF    PTS      FG%  Pos_G  Pos_F  Pos_C
# 0  0.80   2.80  0.35500      1      0      0
# 1  3.30   7.70  0.67500      0      1      0
# 2  2.00  16.30  0.50600      1      0      0
# 3  1.40   9.70  0.52000      0      1      0
# 4  2.35   9.95  0.58875      0      1      0

# %%
player_stats_wout_prospects.columns
# Out:
# Index(['Player', '2P', '3P', 'FT', 'ORB', 'DRB', 'AST', 'STL', 'BLK', 'TOV',
#        'PF', 'PTS', 'FG%', 'Pos_G', 'Pos_F', 'Pos_C'],
#       dtype='object')

# %% [markdown]
# Scaling Numerical data for NBA and prospect datasets separately

# %%
from sklearn.preprocessing import StandardScaler

num_features = ['2P', '3P', 'FT', 'ORB', 'DRB', 'AST', 'STL', 'BLK', 'TOV',
       'PF', 'PTS', 'FG%']

players_num = player_stats_wout_prospects[num_features]
prospects_num = prospect_stats[num_features]

scaler = StandardScaler()
scaler.fit(players_num)
players_scaled = scaler.transform(players_num)
prospects_scaled = scaler.transform(prospects_num)


players_scaled = pd.DataFrame(players_scaled, columns=num_features)
prospects_scaled = pd.DataFrame(prospects_scaled, columns=num_features)

# %% [markdown]
# Readding in position features since we didn't want them to be scaled.

# %%
players_scaled["Pos_G"] = list(player_stats_wout_prospects["Pos_G"])
players_scaled["Pos_F"] = list(player_stats_wout_prospects["Pos_F"])
players_scaled["Pos_C"] = list(player_stats_wout_prospects["Pos_C"])
players_scaled
# Out:
#            2P        3P        FT       ORB       DRB       AST       STL  \
# 0   -1.338390  0.961822 -1.469176 -0.914384 -0.544627 -0.840002 -1.155990
# 1    0.060985  1.583758  0.358036 -0.804885 -0.405676  1.247274  0.612678
# 2    0.650195 -0.779598 -0.721680  1.166082  0.914360 -0.207494 -0.369915
# 3    0.355590 -1.277147 -0.417145  1.202582  0.590141 -0.586999 -1.352509
# 4   -0.344097  1.334983  0.607202 -1.352376 -0.787791  1.753280  0.219641
# ..        ...       ...       ...       ...       ...       ...       ...
# 566 -0.822831  1.086209 -0.306404 -0.476391 -0.544627 -0.523748  0.809197
# 567 -0.380923 -0.903985 -0.057239  0.071100  0.150129 -1.219507 -1.155990
# 568 -1.191088  0.339886 -1.303066 -1.242878 -1.308858 -0.333996 -0.369915
# 569  0.355590 -1.277147 -0.389460  1.604075 -0.266725 -0.840002 -0.762953
# 570  3.301643 -0.406437  0.856367  2.042068  0.983836 -0.144244  1.988309
#
#           BLK       TOV        PF       PTS       FG%  Pos_G  Pos_F  Pos_C
# 0   -0.319348 -1.955124 -2.410587 -0.762677  0.020852    0.0    1.0    0.0
# 1   -0.811510  0.747265  0.619594  1.107060 -0.471014    1.0    0.0    0.0
# 2    0.172813 -0.817276  0.403152 -0.250420  0.050662    0.0    1.0    0.0
# 3    0.500921 -0.343173  0.114564 -0.685839  0.954901    0.0    0.0    1.0
# 4   -0.811510  1.600651  0.511373  0.748480 -0.277248    1.0    0.0    0.0
# ..        ...       ...       ...       ...       ...    ...    ...    ...
# 566 -0.442389 -0.106121 -0.895497  0.005708 -0.500824    1.0    0.0    0.0
# 567  1.157136 -0.675045  1.052477 -0.865128  2.390752    0.0    1.0    0.0
# 568 -0.811510 -1.243969 -0.462614 -1.018805 -0.754209    1.0    0.0    0.0
# 569 -0.196308 -0.532814 -0.895497 -0.660226  1.421925    0.0    0.0    1.0
# 570  1.157136  0.605034 -0.246172  2.362089  2.808093    0.0    1.0    0.0
#
# [571 rows x 15 columns]

# %%
prospects_scaled["Pos_G"] = list(prospect_stats["Pos_G"])
prospects_scaled["Pos_F"] = list(prospect_stats["Pos_F"])
prospects_scaled["Pos_C"] = list(prospect_stats["Pos_C"])
prospects_scaled.head()
# Out:
#          2P        3P        FT       ORB       DRB       AST       STL  \
# 0 -2.148555 -0.903985 -2.133617 -1.461875 -2.073089 -1.029754 -1.745546
# 1 -0.380923 -1.277147 -1.220011  0.618591 -0.683578 -1.029754 -0.959471
# 2  1.018452 -0.530824  1.354698 -1.461875 -1.100431  1.753280  0.416160
# 3 -0.454574 -0.530824 -0.970845 -0.257394 -0.683578 -0.903253 -1.155990
# 4 -0.067905 -0.872888 -0.908554  0.098475 -0.266725 -0.191682  0.710938
#
#         BLK       TOV        PF       PTS       FG%  Pos_G  Pos_F  Pos_C
# 0 -0.934550 -1.955124 -3.059912 -2.709252 -2.036042      1      0      0
# 1  1.034096 -0.959507  2.351126 -1.454224  2.733568      0      1      0
# 2 -0.688469  0.320572 -0.462614  0.748480  0.214618      1      0      0
# 3  0.541934 -1.243969 -1.761263 -0.941967  0.423288      0      1      0
# 4 -0.350108 -1.172853  0.294932 -0.877935  1.448009      0      1      0

# %% [markdown]
# Use KNN to find the closest NBA player comparisons for each of the prospects

# %%
from sklearn.neighbors import NearestNeighbors
import json

rookie_college_comparisons = {}
knn = NearestNeighbors(n_neighbors=4)
knn.fit(players_scaled)
for i in range(len(prospects_scaled)):
    prospect = prospects_scaled.iloc[i].to_numpy().reshape(1,-1)
    dists, idxs = knn.kneighbors(prospect)
    idxs = idxs[0].tolist()
    dists = dists[0].tolist()
    p_name = prospect_stats.iloc[i]["Player"]
    rookie_college_comparisons[p_name] = []
    for j in range(len(idxs)):
        comp_idx = idxs[j]
        comp_dist = dists[j]
        rookie_college_comparisons[p_name].append(player_stats_wout_prospects.iloc[comp_idx]["Player"])
with open('../data/interim/rookie_player_comps.json', 'w') as f:
    json.dump(rookie_college_comparisons, f)
# Out:
# /Users/ncantalupa/opt/miniconda3/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# /Users/ncantalupa/opt/miniconda3/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# /Users/ncantalupa/opt/miniconda3/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# /Users/ncantalupa/opt/miniconda3/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# /Users/ncantalupa/opt/miniconda3/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# /Users/ncantalupa/opt/miniconda3/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# /Users/ncantalupa/opt/miniconda3/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# /Users/ncantalupa/opt/miniconda3/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# /Users/ncantalupa/opt/miniconda3/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# /Users/ncantalupa/opt/miniconda3/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# /Users/ncantalupa/opt/miniconda3/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# /Users/ncantalupa/opt/miniconda3/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# /Users/ncantalupa/opt/miniconda3/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# /Users/ncantalupa/opt/miniconda3/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# /Users/ncantalupa/opt/miniconda3/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# /Users/ncantalupa/opt/miniconda3/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# /Users/ncantalupa/opt/miniconda3/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# /Users/ncantalupa/opt/miniconda3/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# /Users/ncantalupa/opt/miniconda3/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# /Users/ncantalupa/opt/miniconda3/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# /Users/ncantalupa/opt/miniconda3/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# /Users/ncantalupa/opt/miniconda3/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# /Users/ncantalupa/opt/miniconda3/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# /Users/ncantalupa/opt/miniconda3/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# /Users/ncantalupa/opt/miniconda3/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# /Users/ncantalupa/opt/miniconda3/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# /Users/ncantalupa/opt/miniconda3/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# /Users/ncantalupa/opt/miniconda3/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# /Users/ncantalupa/opt/miniconda3/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# /Users/ncantalupa/opt/miniconda3/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# /Users/ncantalupa/opt/miniconda3/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# /Users/ncantalupa/opt/miniconda3/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# /Users/ncantalupa/opt/miniconda3/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# /Users/ncantalupa/opt/miniconda3/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# /Users/ncantalupa/opt/miniconda3/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# /Users/ncantalupa/opt/miniconda3/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# /Users/ncantalupa/opt/miniconda3/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# /Users/ncantalupa/opt/miniconda3/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# /Users/ncantalupa/opt/miniconda3/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# /Users/ncantalupa/opt/miniconda3/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# /Users/ncantalupa/opt/miniconda3/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# /Users/ncantalupa/opt/miniconda3/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# /Users/ncantalupa/opt/miniconda3/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# /Users/ncantalupa/opt/miniconda3/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# /Users/ncantalupa/opt/miniconda3/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# /Users/ncantalupa/opt/miniconda3/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# /Users/ncantalupa/opt/miniconda3/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# /Users/ncantalupa/opt/miniconda3/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# /Users/ncantalupa/opt/miniconda3/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# /Users/ncantalupa/opt/miniconda3/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# /Users/ncantalupa/opt/miniconda3/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# /Users/ncantalupa/opt/miniconda3/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# /Users/ncantalupa/opt/miniconda3/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# /Users/ncantalupa/opt/miniconda3/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(

# %% [markdown]
# Closest player comparison for each comparisons for each prospect

# %%
rookie_college_comparisons
# Out:
# {'AJ Johnson': ['Landry Fields',
#   'Chandler Hutchison',
#   'Immanuel Quickley',
#   'Peyton Watson'],
#  'Adem Bona': ['Zach Collins', 'Jeremy Evans', 'Quincy Acy', 'Daniel Gafford'],
#  'Ajay Mitchell': ['Semaj Christon',
#   "De'Aaron Fox",
#   'Shai Gilgeous-Alexander',
#   'Ray McCallum'],
#  'Alexandre Sarr': ['Jon Leuer',
#   'Cory Jefferson',
#   'Nassir Little',
#   'D.J. Wilson'],
#  'Anton Watson': ['Derrick Brown',
#   'Mitch McGary',
#   'Kendall Brown',
#   'James Augustine'],
#  'Antonio Reeves': ['Luke Kennard',
#   'Arron Afflalo',
#   'Tim Hardaway Jr.',
#   'Tyler Dorsey'],
#  'Ariel Hukporti': ['Markieff Morris',
#   'Festus Ezeli',
#   'Daniel Oturu',
#   'Cedric Simmons'],
#  'Baylor Scheierman': ['Daniel Hamilton',
#   'Allen Crabbe',
#   'Denzel Valentine',
#   'Jordan Nwora'],
#  'Blake Hinson': ['Joe Harris',
#   'Quentin Grimes',
#   'Frank Jackson',
#   'Hamidou Diallo'],
#  'Bobi Klintman': ['Abdel Nader',
#   'DaJuan Summers',
#   'Eric Paschall',
#   'Ryan Kelly'],
#  'Cam Spencer': ['Landry Shamet',
#   'Gary Harris',
#   'Patrick Beverley',
#   'Darrun Hilliard'],
#  'Cody Williams': ['Kelly Olynyk',
#   'Sam Young',
#   'Eric Paschall',
#   'Malaki Branham'],
#  'DaRon Holmes II': ['Nick Fazekas',
#   'Brandon Bass',
#   'Mike Muscala',
#   'Evan Mobley'],
#  'Dalton Knecht': ['Casey Jacobsen',
#   'Malik Monk',
#   'Jordan McRae',
#   'Bennedict Mathurin'],
#  'Devin Carter': ['Nick Johnson',
#   'Devin Harris',
#   'Jarrett Culver',
#   'Darrun Hilliard'],
#  'Donovan Clingan': ['Josh Boone',
#   'Mark Williams',
#   'Joakim Noah',
#   'Byron Mullens'],
#  'Enrique Freeman': ['Bruno Fernando',
#   'Andrew Bogut',
#   'Domantas Sabonis',
#   'Blake Griffin'],
#  'Grant Nelson': ['Austin Daye',
#   'Jaren Jackson Jr.',
#   'Reggie Perry',
#   'Tyler Lydon'],
#  'Harrison Ingram': ['Chandler Parsons',
#   'Josh Childress',
#   'Tyrese Martin',
#   'Robbie Hummel'],
#  'Isaac Jones': ['Patrick Patterson',
#   'Mike Scott',
#   'Rui Hachimura',
#   'Anthony Bennett'],
#  'Jalen Bridges': ['Saddiq Bey',
#   'Danny Green',
#   'Corey Kispert',
#   'Isaiah Livers'],
#  'Jamal Shead': ['Antonio Burks',
#   'Chris Duhon',
#   'Gabe Pruitt',
#   'Payton Pritchard'],
#  'Jared McCain': ['Joe Wieskamp',
#   'Davon Reed',
#   'Ochai Agbaji',
#   'Wayne Ellington'],
#  'Jaylen Wells': ['Semi Ojeleye',
#   'Corey Kispert',
#   'Steve Novak',
#   'Rodney Carney'],
#  'Johnny Furphy': ['Vince Williams Jr.',
#   'Darius Miller',
#   'Sterling Brown',
#   'Daequan Cook'],
#  'Justin Edwards': ['Terrence Ross',
#   'Darius Miller',
#   'Josh Richardson',
#   'Zach LaVine'],
#  'KJ Simpson': ['Aaron Brooks',
#   "D'Angelo Russell",
#   'Delonte West',
#   'Sam Merrill'],
#  'Keshad Johnson': ['Kyle Kuzma',
#   'Nassir Little',
#   'Cory Jefferson',
#   'Darnell Jackson'],
#  'Kevin McCullar Jr.': ['Bruce Brown',
#   'Patrick Beverley',
#   'Talen Horton-Tucker',
#   'Will Barton'],
#  'Kyle Filipowski': ['Kirk Haston',
#   'Jarrell Brantley',
#   'Damion James',
#   'Paul Davis'],
#  'Melvin Ajinca': ['Semi Ojeleye',
#   'Terrence Ross',
#   'Saddiq Bey',
#   'Zach LaVine'],
#  "N'Faly Dante": ['Jahlil Okafor',
#   'Brandon Clarke',
#   'Zion Williamson',
#   'Melvin Ely'],
#  'Nikola Djurisic': ['Keon Johnson',
#   'Marquis Teague',
#   'Khris Middleton',
#   'Tyshawn Taylor'],
#  'Nikola Topic': ['Tyshawn Taylor',
#   'Marquis Teague',
#   'Davion Mitchell',
#   'Keon Johnson'],
#  'Oso Ighodaro': ['Derrick Brown',
#   'Julian Wright',
#   'Montrezl Harrell',
#   'David Lee'],
#  'PJ Hall': ['Jarrell Brantley',
#   'Jayson Tatum',
#   'Georges Niang',
#   'Dahntay Jones'],
#  'Pacome Dadiet': ['Elliot Williams',
#   'Landry Fields',
#   'Chandler Hutchison',
#   'Immanuel Quickley'],
#  'Pelle Larsson': ['Frank Jackson',
#   'Sterling Brown',
#   'Joe Harris',
#   'Kadeem Allen'],
#  'Reece Beekman': ['Tre Jones',
#   'Monte Morris',
#   'Tyler Ulis',
#   'TyTy Washington Jr.'],
#  'Reed Sheppard': ['Shane Larkin',
#   'Mario Chalmers',
#   'Kennedy Chandler',
#   'Dee Brown'],
#  'Rob Dillingham': ['Willie Warren',
#   "E'Twaun Moore",
#   'Jared Butler',
#   'Aaron Brooks'],
#  'Ryan Dunn': ['Willie Cauley-Stein',
#   'Jordan Bell',
#   'Walker Kessler',
#   'Steven Adams'],
#  'Stephon Castle': ['Travis Hansen',
#   'Terance Mann',
#   'Hamidou Diallo',
#   "De'Andre Hunter"],
#  'Terrence Shannon Jr.': ['Austin Rivers',
#   'Jaden Ivey',
#   'Markel Brown',
#   'Bracey Wright'],
#  'Tidjane Salaun': ['DaJuan Summers',
#   'Abdel Nader',
#   'Khris Middleton',
#   'Saddiq Bey'],
#  'Trey Alexander': ['Nickeil Alexander-Walker',
#   'Jaden Ivey',
#   'Caris LeVert',
#   'Anthony Brown'],
#  'Tristen Newton': ['Lamar Patterson',
#   'Shelvin Mack',
#   'Marcus Williams',
#   'Mo Williams'],
#  'Tyler Kolek': ['Steve Blake',
#   'Chris Duhon',
#   'Lorenzo Brown',
#   'Deron Williams'],
#  'Tyler Smith': ['Michael Kidd-Gilchrist',
#   'Jarron Collins',
#   'Solomon Hill',
#   'Cody Martin'],
#  'Tyon Grant-Foster': ['Sindarius Thornwell',
#   'Courtney Lee',
#   'Andrew Wiggins',
#   'James Anderson'],
#  'Yves Missi': ['Quincy Acy',
#   'Dexter Pittman',
#   'Jeremy Evans',
#   'Chimezie Metu'],
#  'Zaccharie Risacher': ['Erik Murphy',
#   'Abdel Nader',
#   'Terrence Ross',
#   'Saddiq Bey'],
#  'Zach Edey': ['Kevin Love', 'Jahlil Okafor', 'Jason Collins', 'Brandon Bass'],
#  'Zyon Pullin': ['Spencer Dinwiddie',
#   'Kemba Walker',
#   'Markel Brown',
#   'Isaiah Thomas']}

# %% [markdown]
# ## Convert College to NBA Numbers

# %%
player_clean = pd.read_csv("../data/processed/player_data_clean.csv")
player_clean = player_clean.drop(['Unnamed: 0'], axis=1)
player_clean
# Out:
#        seas_id  season  player_id           player  age  experience   tm   g  \
# 0        31137    2024       5026      A.J. Lawson   23           2  DAL  42
# 1        30459    2023       5026      A.J. Lawson   22           1  TOT  15
# 2        30461    2023       5026      A.J. Lawson   22           1  DAL  14
# 3        31138    2024       5027       AJ Griffin   20           2  ATL  20
# 4        30467    2023       5027       AJ Griffin   19           1  ATL  72
# ...        ...     ...        ...              ...  ...         ...  ...  ..
# 11602    15597    1997       2546      Stacey King   30           8  TOT  11
# 11603    15605    1997       3027      Steve Hamer   23           1  BOS  35
# 11604    15633    1997       2692      Tracy Moore   31           5  HOU  27
# 11605    15652    1997       2277   Wayman Tisdale   32          12  PHO  53
# 11606    15655    1997       2478  Willie Anderson   30           9  MIA  28
#
#          gs    mp  ...  bpm  vorp  person_id  height  weight  pos_PG  pos_SG  \
# 0       0.0   311  ... -4.6  -0.2    1630639      78   179.0   False    True
# 1       0.0   108  ... -4.4  -0.1    1630639      78   179.0   False    True
# 2       0.0   106  ... -4.6  -0.1    1630639      78   179.0   False    True
# 3       0.0   171  ... -9.6  -0.3    1631100      78   220.0   False   False
# 4      12.0  1401  ... -0.8   0.4    1631100      78   220.0   False   False
# ...     ...   ...  ...  ...   ...        ...     ...     ...     ...     ...
# 11602   0.0   103  ... -7.3  -0.1        351      83   250.0   False   False
# 11603   3.0   268  ... -6.5  -0.3        984      84   245.0   False   False
# 11604   1.0   237  ... -2.9  -0.1        929      76   200.0   False    True
# 11605  15.0   778  ... -8.3  -1.2         47      81   260.0   False   False
# 11606   1.0   303  ...  0.9   0.2        335      80   200.0   False    True
#
#        pos_PF  pos_SF  pos_C
# 0       False   False  False
# 1       False   False  False
# 2       False   False  False
# 3       False    True  False
# 4       False    True  False
# ...       ...     ...    ...
# 11602   False   False   True
# 11603   False   False   True
# 11604   False   False  False
# 11605    True   False  False
# 11606   False   False  False
#
# [11607 rows x 77 columns]

# %%
player_clean = player_clean.drop(["seas_id", "season", "player_id", "age", "experience", "tm", "person_id"], axis = 1)
player_clean
# Out:
#                 player   g    gs    mp  fg_per_100_poss  fga_per_100_poss  \
# 0          A.J. Lawson  42   0.0   311              8.3              18.7
# 1          A.J. Lawson  15   0.0   108             10.1              20.2
# 2          A.J. Lawson  14   0.0   106              9.8              20.2
# 3           AJ Griffin  20   0.0   171              5.0              17.4
# 4           AJ Griffin  72  12.0  1401              8.4              18.1
# ...                ...  ..   ...   ...              ...               ...
# 11602      Stacey King  11   0.0   103              5.6              11.2
# 11603      Steve Hamer  35   3.0   268              5.6              10.7
# 11604      Tracy Moore  27   1.0   237              7.3              18.8
# 11605   Wayman Tisdale  53  15.0   778             10.5              24.6
# 11606  Willie Anderson  28   1.0   303              5.2              11.5
#
#        x3p_per_100_poss  x3pa_per_100_poss  x2p_per_100_poss  \
# 0                   2.0                7.7               6.3
# 1                   4.6               11.5               5.5
# 2                   4.7               11.7               5.2
# 3                   2.8               10.9               2.2
# 4                   3.4                8.8               5.0
# ...                 ...                ...               ...
# 11602               0.0                0.0               5.6
# 11603               0.0                0.4               5.6
# 11604               2.4                9.5               4.9
# 11605               0.0                0.0              10.5
# 11606               1.4                3.4               3.8
#
#        x2pa_per_100_poss  ...  dbpm  bpm  vorp  height  weight  pos_PG  \
# 0                   11.0  ...  -1.5 -4.6  -0.2      78   179.0   False
# 1                    8.7  ...  -2.9 -4.4  -0.1      78   179.0   False
# 2                    8.4  ...  -3.1 -4.6  -0.1      78   179.0   False
# 3                    6.5  ...  -3.5 -9.6  -0.3      78   220.0   False
# 4                    9.3  ...  -0.5 -0.8   0.4      78   220.0   False
# ...                  ...  ...   ...  ...   ...     ...     ...     ...
# 11602               11.2  ...  -2.1 -7.3  -0.1      83   250.0   False
# 11603               10.3  ...  -2.2 -6.5  -0.3      84   245.0   False
# 11604                9.3  ...  -1.5 -2.9  -0.1      76   200.0   False
# 11605               24.6  ...  -2.4 -8.3  -1.2      81   260.0   False
# 11606                8.1  ...   2.2  0.9   0.2      80   200.0   False
#
#        pos_SG  pos_PF  pos_SF  pos_C
# 0        True   False   False  False
# 1        True   False   False  False
# 2        True   False   False  False
# 3       False   False    True  False
# 4       False   False    True  False
# ...       ...     ...     ...    ...
# 11602   False   False   False   True
# 11603   False   False   False   True
# 11604    True   False   False  False
# 11605   False    True   False  False
# 11606    True   False   False  False
#
# [11607 rows x 70 columns]

# %% [markdown]
# Generates projected NBA stats for prospects based on the average of their player comparisons

# %%
rookie_projections = pd.DataFrame(columns=player_clean.columns)
num_cols = player_clean.select_dtypes(include=['number']).columns.tolist()

for pspct in rookie_college_comparisons.keys():
    new_row = {'player': pspct}
    t2 = pd.DataFrame(columns=num_cols)
    for comp in rookie_college_comparisons[pspct]:
        temp = player_clean[player_clean['player'] == comp]
        temp = temp[num_cols]
        t2 = pd.concat([t2, temp], ignore_index=True)
    for c in t2.columns:
        new_row[c] = t2[c].mean()
    new_row.update({"pos_PG":None,"pos_SG":None,"pos_SF":None,"pos_PF":None,"pos_C":None})
    rookie_projections = pd.concat([rookie_projections, pd.DataFrame(new_row, index=[0])], ignore_index=True)
rookie_projections
# Out:
# /var/folders/z9/9fp5jhgs2bj9rb5803bf8zmw0000gn/T/ipykernel_32907/3217251291.py:10: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   t2 = pd.concat([t2, temp], ignore_index=True)
# /var/folders/z9/9fp5jhgs2bj9rb5803bf8zmw0000gn/T/ipykernel_32907/3217251291.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#
# 34          16.053125  ...  0.143750  0.987500  1.131250  80.125000
# 35          11.214286  ... -0.110714 -1.685714  0.732143  78.714286
# 36          10.555556  ... -0.122222 -1.166667  0.444444  76.777778
# 37           7.071429  ... -0.609524 -2.442857  0.109524  76.476190
# 38          11.026667  ... -0.326667 -1.500000  0.386667  73.333333
# 39           8.200000  ...  0.362500 -1.166667  0.404167  72.625000
# 40          11.146429  ... -0.732143 -1.925000  0.110714  73.428571
# 41          11.892308  ...  0.730769  0.000000  0.826923  82.846154
# 42          11.827778  ... -0.300000 -2.227778 -0.044444  77.888889
# 43           9.154545  ... -0.581818 -2.972727 -0.340909  75.863636
# 44          11.111538  ... -0.415385 -1.080769  0.719231  78.730769
# 45          11.764000  ... -0.340000 -1.508000  0.216000  77.560000
# 46          14.305000  ... -1.270000 -2.400000  0.200000  74.700000
# 47           8.533333  ... -0.520833 -0.758333  0.829167  74.791667
# 48           8.071429  ... -0.022857 -3.402857 -0.068571  79.571429
# 49          10.846341  ... -0.095122 -1.317073  0.307317  77.658537
# 50          10.500000  ...  0.080000 -1.972000  0.088000  80.440000
# 51           8.781481  ... -0.311111 -1.648148  0.325926  78.740741
# 52          11.954717  ... -0.194340 -1.335849  0.635849  81.471698
# 53          12.246512  ... -1.039535  0.167442  1.355814  72.837209
#
#         weight  pos_PG  pos_SG  pos_PF  pos_SF  pos_C
# 0   203.235294    None    None    None    None   None
# 1   232.200000    None    None    None    None   None
# 2   189.736842    None    None    None    None   None
# 3   226.400000    None    None    None    None   None
# 4   235.250000    None    None    None    None   None
# 5   204.333333    None    None    None    None   None
# 6   245.535714    None    None    None    None   None
# 7   217.869565    None    None    None    None   None
# 8   210.583333    None    None    None    None   None
# 9   235.333333    None    None    None    None   None
# 10  194.358974    None    None    None    None   None
# 11  233.653846    None    None    None    None   None
# 12  241.000000    None    None    None    None   None
# 13  199.238095    None    None    None    None   None
# 14  190.586207    None    None    None    None   None
# 15  246.541667    None    None    None    None   None
# 16  249.400000    None    None    None    None   None
# 17  230.368421    None    None    None    None   None
# 18  220.166667    None    None    None    None   None
# 19  234.648649    None    None    None    None   None
# 20  218.120000    None    None    None    None   None
# 21  189.411765    None    None    None    None   None
# 22  207.925926    None    None    None    None   None
# 23  224.379310    None    None    None    None   None
# 24  215.500000    None    None    None    None   None
# 25  205.000000    None    None    None    None   None
# 26  178.350000    None    None    None    None   None
# 27  228.058824    None    None    None    None   None
# 28  189.465116    None    None    None    None   None
# 29  252.714286    None    None    None    None   None
# 30  212.105263    None    None    None    None   None
# 31  259.416667    None    None    None    None   None
# 32  205.909091    None    None    None    None   None
# 33  190.153846    None    None    None    None   None
# 34  239.437500    None    None    None    None   None
# 35  223.392857    None    None    None    None   None
# 36  201.388889    None    None    None    None   None
# 37  214.047619    None    None    None    None   None
# 38  182.066667    None    None    None    None   None
# 39  184.791667    None    None    None    None   None
# 40  175.500000    None    None    None    None   None
# 41  246.307692    None    None    None    None   None
# 42  211.055556    None    None    None    None   None
# 43  198.681818    None    None    None    None   None
# 44  223.038462    None    None    None    None   None
# 45  205.720000    None    None    None    None   None
# 46  202.175000    None    None    None    None   None
# 47  186.125000    None    None    None    None   None
# 48  232.371429    None    None    None    None   None
# 49  209.390244    None    None    None    None   None
# 50  229.200000    None    None    None    None   None
# 51  212.407407    None    None    None    None   None
# 52  254.490566    None    None    None    None   None
# 53  195.441860    None    None    None    None   None
#
# [54 rows x 70 columns]

# %%
rookie_projections.to_csv('../data/interim/rookie_projection_stats.csv', index=False)

# %% [markdown]
# ## NBA Players for All Star Comparisons

# %% [markdown]
# Read in and clean data file of 10000 NBA player stats

# %%
nba_df = pd.read_csv('../data/interim/all_player_stats_00-24.csv')
nba_df = nba_df.drop(['Rk', 'MP/G', '-9999'], axis=1)
temp = nba_df["Pos"].str.get_dummies(sep='-')
nba_df["Pos_G"] = list(temp["G"])
nba_df["Pos_F"] = list(temp["F"])
nba_df["Pos_C"] = list(temp["C"])
nba_df = nba_df.drop(["Pos"], axis=1)
nba_df
# Out:
#                Player    WS   Season  Age    Team   G  GS  AS    MP    FG  \
# 0        LeBron James  20.3  2008-09   24     CLE  81  81   1  37.7   9.7
# 1        LeBron James  19.3  2012-13   28     MIA  76  76   1  37.9  10.1
# 2        Kevin Durant  19.2  2013-14   25     OKC  81  81   1  38.5  10.5
# 3        Kevin Durant  18.9  2012-13   24     OKC  81  81   1  38.5   9.0
# 4        LeBron James  18.5  2009-10   25     CLE  76  76   1  39.0  10.1
# ...               ...   ...      ...  ...     ...  ..  ..  ..   ...   ...
# 9995  Stephon Marbury  -0.3  2008-09   31     BOS  23   4   0  18.0   1.7
# 9996         Art Long  -0.3  2002-03   30  PHITOR  26   0   0   8.1   1.1
# 9997   Jamaal Tinsley  -0.3  2009-10   31     MEM  38   1   0  15.5   1.4
# 9998       Eddy Curry  -0.3  2009-10   27     NYK   7   0   0   8.9   1.1
# 9999      Evan Turner  -0.3  2019-20   31     ATL  19   0   0  13.2   1.3
#
#       ...   PTS    FG%    2P%    3P%    FT%    TS%    eFG%  Pos_G  Pos_F  \
# 0     ...  28.4  0.489  0.535  0.344  0.780  0.591  53.007      1      1
# 1     ...  26.8  0.565  0.602  0.406  0.753  0.640  60.303      1      1
# 2     ...  32.0  0.503  0.549  0.391  0.873  0.635  55.983      1      1
# 3     ...  28.1  0.510  0.539  0.416  0.905  0.647  55.862      1      1
# 4     ...  29.7  0.503  0.560  0.333  0.767  0.604  54.483      1      1
# ...   ...   ...    ...    ...    ...    ...    ...     ...    ...    ...
# 9995  ...   3.8  0.342  0.372  0.240  0.462  0.377  36.937      1      0
# 9996  ...   2.3  0.373  0.361  0.667  0.200  0.378  38.667      0      1
# 9997  ...   3.5  0.371  0.446  0.179  0.815  0.438  39.643      1      0
# 9998  ...   3.7  0.381  0.381    NaN  0.588  0.456  38.095      0      0
# 9999  ...   3.3  0.373  0.403  0.000  0.857  0.424  37.313      1      0
#
#       Pos_C
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
# ...     ...
# 9995      0
# 9996      1
# 9997      0
# 9998      1
# 9999      0
#
# [10000 rows x 35 columns]

# %% [markdown]
# Scale NBA player data

# %%
num_features = ['2P', '3P', 'FT', 'ORB', 'DRB', 'AST', 'STL', 'BLK', 'TOV',
       'PF', 'PTS', 'FG%']

nba_num = nba_df[num_features]

nba_scaler = StandardScaler()
nba_scaler.fit(nba_num)
nba_scaled = nba_scaler.transform(nba_num)
nba_scaled = pd.DataFrame(nba_scaled, columns=num_features)
nba_scaled["Pos_G"] = nba_df["Pos_G"]
nba_scaled["Pos_F"] = nba_df["Pos_F"]
nba_scaled["Pos_C"] = nba_df["Pos_C"]
nba_scaled
# Out:
#             2P        3P        FT       ORB       DRB       AST       STL  \
# 0     2.858490  1.107670  3.978301  0.346113  1.926263  2.804234  2.412826
# 1     3.176958  0.847106  2.575201  0.346113  2.212675  2.858788  2.412826
# 2     2.858490  2.149925  4.960471 -0.393550  2.155393  1.876825  1.446401
# 3     2.433867  1.237952  4.750006 -0.516827  2.499087  1.385844  1.688007
# 4     3.017724  1.237952  4.329076 -0.146996  1.983546  3.567983  2.171220
# ...        ...       ...       ...       ...       ...       ...       ...
# 9995 -0.697731 -0.585995 -0.932549 -1.133213 -1.052421  0.676649 -0.728057
# 9996 -0.910042 -0.846559 -1.072859 -0.270273 -0.823291 -1.014509 -1.211269
# 9997 -0.803886 -0.716277 -0.722084 -0.886658 -0.880573  0.403881  0.479975
# 9998 -0.856964 -0.976841 -0.160844 -0.516827 -0.937856 -1.123616 -1.694482
# 9999 -0.750808 -0.976841 -0.722084 -0.763381 -0.766009 -0.032547 -0.486450
#
#            BLK       TOV        PF       PTS       FG%  Pos_G  Pos_F  Pos_C
# 0     1.376541  2.243211 -0.360287  3.222512  0.534411      1      1      0
# 1     0.950954  2.243211 -0.786226  2.952487  1.564896      1      1      0
# 2     0.525366  2.888223  0.207631  3.830067  0.724238      1      1      0
# 3     1.802129  2.888223 -0.218308  3.171882  0.819151      1      1      0
# 4     1.163748  2.759221 -0.502267  3.441907  0.724238      1      1      0
# ...        ...       ...       ...       ...       ...    ...    ...    ...
# 9995 -0.751396  0.437176 -0.644247 -0.929118 -1.458763      1      0      0
# 9996 -0.113015 -0.594843 -0.928206 -1.182266 -1.038434      0      1      1
# 9997 -0.751396  0.566179 -0.218308 -0.979747 -1.065552      1      0      0
# 9998 -0.751396  0.824184 -0.076328 -0.945994 -0.929962      0      0      1
# 9999 -0.113015  0.179172 -1.212165 -1.013501 -1.038434      1      0      0
#
# [10000 rows x 15 columns]

# %% [markdown]
# # All Star Comparisons

# %% [markdown]
# Read in dataset of NBA all stars

# %%
all_star_stats = pd.read_csv("../data/interim/allstar_stats_00-24.csv")
all_star_stats = all_star_stats.drop(['Rk', '-9999'], axis=1)
all_star_stats
# Out:
#               Player    WS   Season  Age Team   G  GS  AS    MP    FG  ...  \
# 0       LeBron James  20.3  2008-09   24  CLE  81  81   1  37.7   9.7  ...
# 1       LeBron James  19.3  2012-13   28  MIA  76  76   1  37.9  10.1  ...
# 2       Kevin Durant  19.2  2013-14   25  OKC  81  81   1  38.5  10.5  ...
# 3       Kevin Durant  18.9  2012-13   24  OKC  81  81   1  38.5   9.0  ...
# 4       LeBron James  18.5  2009-10   25  CLE  76  76   1  39.0  10.1  ...
# ..               ...   ...      ...  ...  ...  ..  ..  ..   ...   ...  ...
# 595   Deron Williams   4.1  2011-12   27  NJN  55  55   1  36.3   7.1  ...
# 596    Tracy McGrady   4.1  2005-06   26  HOU  47  47   1  37.1   8.7  ...
# 597    Julius Randle   3.8  2023-24   29  NYK  46  46   1  35.4   8.6  ...
# 598  Anthony Edwards   3.8  2022-23   21  MIN  79  79   1  36.0   8.9  ...
# 599  Jermaine O'Neal   3.8  2004-05   26  IND  44  41   1  34.8   8.8  ...
#
#      TOV   PF   PTS    FG%    2P%    3P%    FT%    TS%    eFG%  Pos
# 0    3.0  1.7  28.4  0.489  0.535  0.344  0.780  0.591  53.007  F-G
# 1    3.0  1.4  26.8  0.565  0.602  0.406  0.753  0.640  60.303  F-G
# 2    3.5  2.1  32.0  0.503  0.549  0.391  0.873  0.635  55.983  F-G
# 3    3.5  1.8  28.1  0.510  0.539  0.416  0.905  0.647  55.862  F-G
# 4    3.4  1.6  29.7  0.503  0.560  0.333  0.767  0.604  54.483  F-G
# ..   ...  ...   ...    ...    ...    ...    ...    ...     ...  ...
# 595  4.0  2.2  21.0  0.407  0.446  0.336  0.843  0.527  46.670    G
# 596  2.6  1.9  24.4  0.406  0.434  0.312  0.747  0.494  44.164  G-F
# 597  3.5  2.7  24.0  0.472  0.539  0.311  0.781  0.569  51.794  F-C
# 598  3.3  2.4  24.6  0.459  0.513  0.369  0.756  0.564  52.790  G-F
# 599  3.0  3.9  24.3  0.452  0.454  0.167  0.754  0.520  45.258  C-F
#
# [600 rows x 33 columns]

# %% [markdown]
# Scale all star dataset

# %%
num_features = ['2P', '3P', 'FT', 'ORB', 'DRB', 'AST', 'STL', 'BLK', 'TOV',
       'PF', 'PTS', 'FG%']

all_stars_num = all_star_stats[num_features]

AS_scaler = StandardScaler()
AS_scaler.fit(all_stars_num)
AS_scaled = scaler.transform(all_stars_num)

AS_scaled = pd.DataFrame(AS_scaled, columns=num_features)
AS_scaled
# Out:
#            2P        3P        FT       ORB       DRB       AST       STL  \
# 0    3.227992  0.713048  3.680240 -0.366893  1.609116  3.081546  1.202234
# 1    3.669900  0.464273  2.019138 -0.366893  1.956493  3.144797  1.202234
# 2    3.227992  1.708145  4.843012 -1.023882  1.887018  2.006283  0.416160
# 3    2.638781  0.837435  4.593846 -1.133380  2.303871  1.437026  0.612678
# 4    3.448946  0.837435  4.095516 -0.804885  1.678591  3.967057  1.005716
# ..        ...       ...       ...       ...       ...       ...       ...
# 595  0.944801  1.334983  1.520808 -1.352376 -0.753053  4.030308  0.219641
# 596  2.565130  0.713048  2.102193 -0.695387  1.122787  1.563527  0.416160
# 597  2.344176  0.837435  1.853028  0.618591  2.095445  1.690029 -1.155990
# 598  1.902268  2.081306  0.939422 -1.133380  0.844884  1.310524  1.005716
# 599  3.743551 -1.277147  3.181910  0.290097  2.025969 -0.270745 -0.959471
#
#           BLK       TOV        PF       PTS       FG%
# 0    0.295853  1.458420 -1.111938  3.847633 -0.038768
# 1    0.049773  1.458420 -1.761263  3.437827  1.094014
# 2   -0.196308  2.169574 -0.246172  4.769695  0.169903
# 3    0.541934  2.169574 -0.895497  3.770794  0.274238
# 4    0.172813  2.027343 -1.328380  4.180600  0.169903
# ..        ...       ...       ...       ...       ...
# 595 -0.565429  2.880729 -0.029731  1.952283 -1.260980
# 596  0.049773  0.889496 -0.679055  2.823119 -1.275885
# 597 -0.688469  2.169574  1.052477  2.720668 -0.292153
# 598 -0.196308  1.885112  0.403152  2.874345 -0.485919
# 599  1.403217  1.458420  3.649775  2.797507 -0.590254
#
# [600 rows x 12 columns]

# %% [markdown]
# Adding Position to the scaled all star data

# %%
temp = all_star_stats["Pos"].str.get_dummies(sep='-')
all_star_stats["Pos_G"] = list(temp["G"])
all_star_stats["Pos_F"] = list(temp["F"])
all_star_stats["Pos_C"] = list(temp["C"])
all_star_stats = all_star_stats.drop(["Pos"], axis=1)
AS_scaled["Pos_G"] = all_star_stats["Pos_G"]
AS_scaled["Pos_F"] = all_star_stats["Pos_F"]
AS_scaled["Pos_C"] = all_star_stats["Pos_C"]
AS_scaled
# Out:
#            2P        3P        FT       ORB       DRB       AST       STL  \
# 0    3.227992  0.713048  3.680240 -0.366893  1.609116  3.081546  1.202234
# 1    3.669900  0.464273  2.019138 -0.366893  1.956493  3.144797  1.202234
# 2    3.227992  1.708145  4.843012 -1.023882  1.887018  2.006283  0.416160
# 3    2.638781  0.837435  4.593846 -1.133380  2.303871  1.437026  0.612678
# 4    3.448946  0.837435  4.095516 -0.804885  1.678591  3.967057  1.005716
# ..        ...       ...       ...       ...       ...       ...       ...
# 595  0.944801  1.334983  1.520808 -1.352376 -0.753053  4.030308  0.219641
# 596  2.565130  0.713048  2.102193 -0.695387  1.122787  1.563527  0.416160
# 597  2.344176  0.837435  1.853028  0.618591  2.095445  1.690029 -1.155990
# 598  1.902268  2.081306  0.939422 -1.133380  0.844884  1.310524  1.005716
# 599  3.743551 -1.277147  3.181910  0.290097  2.025969 -0.270745 -0.959471
#
#           BLK       TOV        PF       PTS       FG%  Pos_G  Pos_F  Pos_C
# 0    0.295853  1.458420 -1.111938  3.847633 -0.038768      1      1      0
# 1    0.049773  1.458420 -1.761263  3.437827  1.094014      1      1      0
# 2   -0.196308  2.169574 -0.246172  4.769695  0.169903      1      1      0
# 3    0.541934  2.169574 -0.895497  3.770794  0.274238      1      1      0
# 4    0.172813  2.027343 -1.328380  4.180600  0.169903      1      1      0
# ..        ...       ...       ...       ...       ...    ...    ...    ...
# 595 -0.565429  2.880729 -0.029731  1.952283 -1.260980      1      0      0
# 596  0.049773  0.889496 -0.679055  2.823119 -1.275885      1      1      0
# 597 -0.688469  2.169574  1.052477  2.720668 -0.292153      0      1      1
# 598 -0.196308  1.885112  0.403152  2.874345 -0.485919      1      1      0
# 599  1.403217  1.458420  3.649775  2.797507 -0.590254      0      1      1
#
# [600 rows x 15 columns]

# %% [markdown]
# testing function for NN search to find nearest all star to all draft prospects

# %%
def find_AS_comparison(player_row_scaled, comp_df):
    knn = NearestNeighbors(n_neighbors=3)
    knn.fit(comp_df)
    dists, idxs = knn.kneighbors(player_row_scaled)
    idxs = idxs[0].tolist()
    return idxs

# %% [markdown]
# Show indexes for prospects

# %%
for i, name in enumerate(prospect_stats['Player']):
    print(f"{i}: {name}")
# Out:
# 0: AJ Johnson
# 1: Adem Bona
# 2: Ajay Mitchell
# 3: Alexandre Sarr
# 4: Anton Watson
# 5: Antonio Reeves
# 6: Ariel Hukporti
# 7: Baylor Scheierman
# 8: Blake Hinson
# 9: Bobi Klintman
# 10: Cam Spencer
# 11: Cody Williams
# 12: DaRon Holmes II
# 13: Dalton Knecht
# 14: Devin Carter
# 15: Donovan Clingan
# 16: Enrique Freeman
# 17: Grant Nelson
# 18: Harrison Ingram
# 19: Isaac Jones
# 20: Jalen Bridges
# 21: Jamal Shead
# 22: Jared McCain
# 23: Jaylen Wells
# 24: Johnny Furphy
# 25: Justin Edwards
# 26: KJ Simpson
# 27: Keshad Johnson
# 28: Kevin McCullar Jr.
# 29: Kyle Filipowski
# 30: Melvin Ajinca
# 31: N'Faly Dante
# 32: Nikola Djurisic
# 33: Nikola Topic
# 34: Oso Ighodaro
# 35: PJ Hall
# 36: Pacome Dadiet
# 37: Pelle Larsson
# 38: Reece Beekman
# 39: Reed Sheppard
# 40: Rob Dillingham
# 41: Ryan Dunn
# 42: Stephon Castle
# 43: Terrence Shannon Jr.
# 44: Tidjane Salaun
# 45: Trey Alexander
# 46: Tristen Newton
# 47: Tyler Kolek
# 48: Tyler Smith
# 49: Tyon Grant-Foster
# 50: Yves Missi
# 51: Zaccharie Risacher
# 52: Zach Edey
# 53: Zyon Pullin

# %%
# Update Based on Player Index above
player_index = 52

player_in = prospects_scaled.iloc[player_index].to_numpy().reshape(1,-1)
comps = find_AS_comparison(player_in, AS_scaled)
print(f"All Star Comparison for {prospect_stats.iloc[player_index, 0]}:")
for i in comps:
    print(f"\t{all_star_stats.iloc[int(i),0]}")
# Out:
# All Star Comparison for Zach Edey:
# 	Brook Lopez
# 	Pau Gasol
# 	Jarrett Allen
# /Users/ncantalupa/opt/miniconda3/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(

# %% [markdown]
# Since the test function appears to be working well, output all processed files to be read in for final app

# %%
AS_scaled.index = all_star_stats["Player"]
AS_scaled.to_csv("../data/processed/all_stars_scaled.csv", index=True)

# %%
rookie_stats = prospect_stats.round(2)
rookie_stats['Pos'] = rookie_stats[['Pos_G', 'Pos_F', 'Pos_C']].idxmax(axis=1)
rookie_stats["Pos"] = rookie_stats["Pos"].replace({'Pos_G': 'G', 'Pos_F': 'F', 'Pos_C': 'C'})
rookie_stats = rookie_stats.drop(['Pos_G', 'Pos_F', 'Pos_C'], axis=1)
cols = list(rookie_stats.columns)
cols.insert(1, cols.pop())
rookie_stats = rookie_stats[cols]
rookie_stats.to_csv("../data/processed/rookie_stats.csv", index=False)

# %%
prospects_scaled.index = rookie_stats["Player"]
prospects_scaled.to_csv('../data/processed/rookie_stats_scaled.csv')
