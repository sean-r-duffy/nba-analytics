# %%
import pandas as pd
import numpy as np

import sys
import os

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path+"\\src\models")

import win_prediction
# Out:
# <>:9: SyntaxWarning: invalid escape sequence '\m'
# <>:9: SyntaxWarning: invalid escape sequence '\m'
# C:\Users\pazin\AppData\Local\Temp\ipykernel_1392\933316663.py:9: SyntaxWarning: invalid escape sequence '\m'
#   sys.path.append(module_path+"\\src\models")

# %%
team_stats_path = '../data/external/NBA_team_stats_1979-2024.csv'
player_stats_path = '../data/processed/player_data_clean.csv'

team_stats = pd.read_csv(team_stats_path, header=1)
player_stats = pd.read_csv(player_stats_path)

# %%
final_df = win_prediction.agg_by_pos(team_stats, player_stats)
final_df
# Out:
#     full_season   tm  pos_PG_fg_per_100_poss  pos_PG_fga_per_100_poss  \
# 1       1997-98  BOS                7.260762                17.634528
# 2       1997-98  CHH                7.210241                15.574443
# 3       1997-98  CHI                5.968318                13.870941
# 4       1997-98  CLE                4.000000                 8.200000
# 5       1997-98  DAL                6.590216                17.010461
# ..          ...  ...                     ...                      ...
# 822     2023-24  PHO               12.329076                25.415729
# 824     2023-24  SAC               11.233138                22.393351
# 825     2023-24  SAS                7.960257                17.881132
# 826     2023-24  TOR                8.347209                18.135814
# 828     2023-24  UTA                9.576572                20.032108
#
#      pos_PG_x3p_per_100_poss  pos_PG_x3pa_per_100_poss  \
# 1                   2.348459                  6.420697
# 2                   1.357956                  4.001975
# 3                   1.464821                  4.228767
# 4                   1.100000                  2.500000
# 5                   2.510403                  6.967061
# ..                       ...                       ...
# 822                 2.682672                  7.579279
# 824                 2.241436                  6.995027
# 825                 1.817210                  6.020388
# 826                 2.882558                  7.871163
# 828                 1.712799                  4.966165
#
#      pos_PG_x2p_per_100_poss  pos_PG_x2pa_per_100_poss  \
# 1                   4.870058                 11.213831
# 2                   5.852285                 11.572468
# 3                   4.503498                  9.708744
# 4                   3.000000                  5.700000
# 5                   4.090458                 10.037456
# ..                       ...                       ...
# 822                 9.723112                 17.830651
# 824                 8.991702                 15.327606
# 825                 6.140702                 11.858399
# 826                 5.464651                 10.282326
# 828                 7.808459                 15.010629
#
#      pos_PG_ft_per_100_poss  pos_PG_fta_per_100_poss  ...  pos_C_dws  \
# 1                  4.594588                 5.578351  ...   1.246365
# 2                  3.628197                 4.573456  ...   3.583232
# 3                  2.167735                 3.068318  ...   0.717859
# 4                  3.000000                 3.200000  ...   3.708125
# 5                  2.986298                 3.922465  ...   1.660139
# ..                      ...                      ...  ...        ...
# 822                6.940391                 8.252743  ...   1.314451
# 824                4.972367                 6.374574  ...   2.631317
# 825                2.828791                 3.357583  ...   0.831468
# 826                3.559070                 4.417907  ...   1.690149
# 828                3.936227                 5.214969  ...   1.925613
#
#       pos_C_ws  pos_C_ws_48  pos_C_obpm  pos_C_dbpm  pos_C_bpm  pos_C_vorp  \
# 1     2.444382     0.103279   -3.005288   -0.304627  -3.309914   -0.352974
# 2     6.709271     0.121801    0.385968    1.777406   2.071935    3.017477
# 3     1.224547     0.077017   -3.796097   -0.156843  -3.929552   -0.357671
# 4     6.085096     0.126054   -1.569982    0.053047  -1.579689    0.796386
# 5     1.539976     0.052147   -2.863951    0.772142  -2.057897    0.151702
# ..         ...          ...         ...         ...        ...         ...
# 822   3.582312     0.136331   -0.764220    0.692601   0.002486    0.624798
# 824  10.980427     0.203093    2.914947    1.694662   4.509609    4.675801
# 825   1.802151     0.076246   -0.644230    0.065515  -0.578714    0.434068
# 826   4.031200     0.126941    0.225670    0.551640   0.720354    1.087886
# 828   5.025679     0.144064    0.265162    0.765162   1.014818    1.407785
#
#       Season  Team  W/L%
# 1    1997-98   BOS  .439
# 2    1997-98   CHH  .622
# 3    1997-98   CHI  .756
# 4    1997-98   CLE  .573
# 5    1997-98   DAL  .244
# ..       ...   ...   ...
# 822  2023-24   PHO  .598
# 824  2023-24   SAC  .561
# 825  2023-24   SAS  .268
# 826  2023-24   TOR  .305
# 828  2023-24   UTA  .378
#
# [692 rows x 300 columns]
