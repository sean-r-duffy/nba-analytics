# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('../data/interim/player_data_aggregated.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  seas_id  season  player_id       player  birth_year pos  age  \
# 0           0    31137    2024       5026  A.J. Lawson         NaN  SG   23
# 1           1    30459    2023       5026  A.J. Lawson         NaN  SG   22
# 2           2    30460    2023       5026  A.J. Lawson         NaN  SG   22
# 3           3    30461    2023       5026  A.J. Lawson         NaN  SG   22
# 4           4    31138    2024       5027   AJ Griffin         NaN  SF   20
#
#    experience   lg  ...  playercode  from_year  to_year  dleague_flag  \
# 0           2  NBA  ...   aj_lawson     2022.0   2023.0             Y
# 1           1  NBA  ...   aj_lawson     2022.0   2023.0             Y
# 2           1  NBA  ...   aj_lawson     2022.0   2023.0             Y
# 3           1  NBA  ...   aj_lawson     2022.0   2023.0             Y
# 4           2  NBA  ...  aj_griffin     2022.0   2023.0             N
#
#    nba_flag  games_played_flag  draft_year  draft_round  draft_number  \
# ...

# %%
df.describe()
# Out:
#          Unnamed: 0       seas_id        season     player_id   birth_year  \
# count  13549.000000  13549.000000  13549.000000  13549.000000   362.000000
# mean    6774.000000  23333.401875   2011.118607   3658.295889  1979.096685
# std     3911.403734   4857.943428      8.195232    682.822117     8.942044
# min        0.000000  15086.000000   1997.000000   1723.000000  1957.000000
# 25%     3387.000000  19067.000000   2004.000000   3116.000000  1975.000000
# 50%     6774.000000  23331.000000   2011.000000   3636.000000  1980.000000
# 75%    10161.000000  27541.000000   2018.000000   4180.000000  1986.000000
# max    13548.000000  31870.000000   2024.000000   5191.000000  2002.000000
#
#                 age    experience            g            gs            mp  \
# count  13549.000000  13549.000000  13549.00000  13549.000000  13549.000000
# mean      26.760425      5.708392     45.42660     21.872832   1064.020740
# ...

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13549 entries, 0 to 13548
# Data columns (total 111 columns):
#  #    Column                            Dtype
# ---   ------                            -----
#  0    Unnamed: 0                        int64
#  1    seas_id                           int64
#  2    season                            int64
#  3    player_id                         int64
#  4    player                            object
#  5    birth_year                        float64
#  6    pos                               object
#  7    age                               int64
#  8    experience                        int64
#  9    lg                                object
#  10   tm                                object
#  11   g                                 int64
#  12   gs                                float64
#  13   mp                                int64
#  14   fg_per_100_poss                   float64
#  15   fga_per_100_poss                  float64
# ...
